# %% [markdown]
# # Introduction to NLTK
#
# In this assignment you will use nltk to explore the Herman Melville novel Moby Dick. Then you will create a spelling recommender function that uses nltk to find words similar to the misspelling.

# %% [markdown]
# ## Part 1 - Analyzing Moby Dick

# %%
import requests

# URL to download Moby Dick text
moby_url = 'https://www.gutenberg.org/files/2701/2701-0.txt'

# Download the file
response = requests.get(moby_url)
response.raise_for_status() # Raise an exception for bad status codes

# Save the content to moby.txt
with open('moby.txt', 'w', encoding='utf-8') as f:
    f.write(response.text)
# Out:
# moby.txt downloaded successfully.

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('words')
import pandas as pd
import numpy as np

# If you would like to work with the raw text you can use 'moby_raw'
with open('moby.txt', 'r') as f:
    moby_raw = f.read()

# If you would like to work with the novel in nltk.Text format you can use 'text1'
moby_tokens = nltk.word_tokenize(moby_raw)
text1 = nltk.Text(moby_tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ### Example 1
#
# How many tokens (words and punctuation symbols) are in text1?
#
# *This function should return an integer.*

# %%
def example_one():

    return len(nltk.word_tokenize(moby_raw)) # or alternatively len(text1)

example_one()
# Out:
# 255988

# %% [markdown]
# ### Example 2
#
# How many unique tokens (unique words and punctuation) does text1 have?
#
# *This function should return an integer.*

# %%
def example_two():

    return len(set(nltk.word_tokenize(moby_raw))) # or alternatively len(set(text1))

example_two()
# Out:
# 21906

# %% [markdown]
# ### Example 3
#
# After lemmatizing the verbs, how many unique tokens does text1 have?
#
# *This function should return an integer.*

# %%
from nltk.stem import WordNetLemmatizer

def example_three():

    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in text1]

    return len(set(lemmatized))

example_three()
# Out:
# 18197

# %% [markdown]
# ### Question 1
#
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)
#
# *This function should return a float.*

# %%
def answer_one():


    return example_two()/example_one()

answer_one()
# Out:
# 0.08557432379642796

# %% [markdown]
# ### Question 2
#
# What percentage of tokens is 'whale'or 'Whale'?
#
# *This function should return a float.*

# %%
def answer_two():


    return (text1.vocab()['whale'] + text1.vocab()['Whale']) / len(nltk.word_tokenize(moby_raw)) * 100 # Your answer here

answer_two()
# Out:
# 0.41486319671234595

# %% [markdown]
# ### Question 3
#
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?
#
# *This function should return a list of 20 tuples where each tuple is of the form `(token, frequency)`. The list should be sorted in descending order of frequency.*

# %%
def answer_three():
    import operator

    return sorted(text1.vocab().items(), key=operator.itemgetter(1), reverse=True)[:20] # Your answer here

answer_three()
# Out:
# [(',', 19212),
#  ('the', 13717),
#  ('.', 7165),
#  ('of', 6563),
#  ('and', 6009),
#  ('to', 4515),
#  ('a', 4507),
#  (';', 4178),
#  ('in', 3915),
#  ('that', 2918),
#  ('’', 2790),
#  ('his', 2457),
#  ('it', 2153),
#  ('I', 2074),
#  ('s', 1785),
#  ('!', 1767),
#  ('is', 1686),
#  ('with', 1661),
#  ('he', 1635),
#  ('was', 1625)]

# %% [markdown]
# ### Question 4
#
# What tokens have a length of greater than 5 and frequency of more than 150?
#
# *This function should return a sorted list of the tokens that match the above constraints. To sort your list, use `sorted()`*

# %%
def answer_four():


    return sorted([token for token, freq in text1.vocab().items() if len(token) > 5 and freq > 150]) # Your answer here

answer_four()
# Out:
# ['CHAPTER',
#  'Captain',
#  'Pequod',
#  'Queequeg',
#  'Starbuck',
#  'almost',
#  'before',
#  'himself',
#  'little',
#  'seemed',
#  'should',
#  'though',
#  'through',
#  'whales',
#  'without']

# %% [markdown]
# ### Question 5
#
# Find the longest word in text1 and that word's length.
#
# *This function should return a tuple `(longest_word, length)`.*

# %%
def answer_five():
    import operator

    return sorted([(token, len(token))for token, freq in text1.vocab().items()], key=operator.itemgetter(1), reverse=True)[0] # Your answer here

answer_five()
# Out:
# ('swayings—coyings—flutterings', 28)

# %% [markdown]
# ### Question 6
#
# What unique words have a frequency of more than 2000? What is their frequency?
#
# "Hint:  you may want to use `isalpha()` to check if the token is a word and not punctuation."
#
# *This function should return a list of tuples of the form `(frequency, word)` sorted in descending order of frequency.*

# %%
def answer_six():
    import operator

    return sorted([(freq, token) for token, freq in text1.vocab().items() if freq > 2000 and token.isalpha()], key=operator.itemgetter(0), reverse=True) # Your answer here

answer_six()
# Out:
# [(13717, 'the'),
#  (6563, 'of'),
#  (6009, 'and'),
#  (4515, 'to'),
#  (4507, 'a'),
#  (3915, 'in'),
#  (2918, 'that'),
#  (2457, 'his'),
#  (2153, 'it'),
#  (2074, 'I')]

# %% [markdown]
# ### Question 7
#
# What is the average number of tokens per sentence?
#
# *This function should return a float.*

# %%
def answer_seven():


    return np.mean([len(nltk.word_tokenize(sent)) for sent in nltk.sent_tokenize(moby_raw)]) # Your answer here

answer_seven()
# Out:
# np.float64(28.23916161059018)

# %% [markdown]
# ### Question 8
#
# What are the 5 most frequent parts of speech in this text? What is their frequency?
#
# *This function should return a list of tuples of the form `(part_of_speech, frequency)` sorted in descending order of frequency.*

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
def answer_eight():
    from collections import Counter
    import operator

    return sorted(Counter([tag for token, tag in nltk.pos_tag(text1)]).items(), key=operator.itemgetter(1), reverse=True)[:5] # Your answer here

answer_eight()
# Out:
# [('NN', 35301), ('IN', 28759), ('DT', 25703), ('JJ', 19270), (',', 19212)]

# %% [markdown]
# ## Part 2 - Spelling Recommender
#
# For this part of the assignment you will create three different spelling recommenders, that each take a list of misspelled words and recommends a correctly spelled word for every word in the list.
#
# For every misspelled word, the recommender should find find the word in `correct_spellings` that has the shortest distance*, and starts with the same letter as the misspelled word, and return that word as a recommendation.
#
# *Each of the three different recommenders will use a different distance measure (outlined below).
#
# Each of the recommenders should provide recommendations for the three default words provided: `['cormulent', 'incendenece', 'validrate']`.

# %%
from nltk.corpus import words

correct_spellings = words.words()

# %% [markdown]
# ### Question 9
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the trigrams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.jaccard_distance(set(nltk.ngrams(entry, n=3)), set(nltk.ngrams(spell, n=3)))) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result # Your answer here

answer_nine()
# Out:
# ['corpulent', 'indecence', 'validate']

# %% [markdown]
# ### Question 10
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the 4-grams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_ten(entries=['cormulent', 'incendenece', 'validrate']):
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.jaccard_distance(set(nltk.ngrams(entry, n=4)), set(nltk.ngrams(spell, n=4)))) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result # Your answer here

answer_ten()
# Out:
# ['cormus', 'incendiary', 'valid']

# %% [markdown]
# ### Question 11
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Edit distance on the two words with transpositions.](https://en.wikipedia.org/wiki/Damerau%E2%80%93Levenshtein_distance)**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_eleven(entries=['cormulent', 'incendenece', 'validrate']):
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.edit_distance(entry, spell, transpositions=True)) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result# Your answer here

answer_eleven()
# Out:
# ['corpulent', 'intendence', 'validate']

# %% [markdown]
# #Ramayana
#
# Do similar text preprocessing using NLTK for ramayana.txt import from https://raw.githubusercontent.com/cltk/sanskrit_parallel_gitasupersite/refs/heads/master/ramayana/aranyakanda_english.txt

# %%
# URL to download Ramayana text
ramayana_url = 'https://raw.githubusercontent.com/cltk/sanskrit_parallel_gitasupersite/refs/heads/master/ramayana/aranyakanda_english.txt'

# Download the file
response = requests.get(ramayana_url)
response.raise_for_status() # Raise an exception for bad status codes

# Save the content to ramayana.txt
with open('ramayana.txt', 'w', encoding='utf-8') as f:
    f.write(response.text)

print("ramayana.txt downloaded successfully.")

# If you would like to work with the raw text you can use 'ramayana_raw'
with open('ramayana.txt', 'r', encoding='utf-8') as f:
    ramayana_raw = f.read()

# If you would like to work with the novel in nltk.Text format you can use 'text_ramayana'
ramayana_tokens = nltk.word_tokenize(ramayana_raw)
text_ramayana = nltk.Text(ramayana_tokens)

print("Ramayana text processed successfully into ramayana_raw, ramayana_tokens, and text_ramayana.")
# Out:
# ramayana.txt downloaded successfully.
# Ramayana text processed successfully into ramayana_raw, ramayana_tokens, and text_ramayana.

# %% [markdown]
# ## Part 1.2 - Analyzing Ramayana

# %% [markdown]
# ### Question 1 (Ramayana)
#
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)
#
# *This function should return a float.*

# %%
def ramayana_answer_one():
    return len(set(ramayana_tokens)) / len(ramayana_tokens)

ramayana_answer_one()
# Out:
# 0.09237603403079725

# %% [markdown]
# ### Question 2 (Ramayana)
#
# What percentage of tokens is 'Rama' or 'RAma'?
#
# *This function should return a float.*

# %%
def ramayana_answer_two():
    # Convert all tokens to lowercase for case-insensitive counting
    lowercase_tokens = [token.lower() for token in ramayana_tokens]

    # Count occurrences of 'rama'
    rama_count = lowercase_tokens.count('rama')

    # Calculate percentage
    return (rama_count / len(ramayana_tokens)) * 100

ramayana_answer_two()
# Out:
# 1.2557489757797418

# %% [markdown]
# ### Question 3 (Ramayana)
#
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?
#
# *This function should return a list of 20 tuples where each tuple is of the form `(token, frequency)`. The list should be sorted in descending order of frequency.*

# %%
import operator

def ramayana_answer_three():
    return sorted(text_ramayana.vocab().items(), key=operator.itemgetter(1), reverse=True)[:20]

ramayana_answer_three()
# Out:
# [(',', 3644),
#  ('the', 3407),
#  ('.', 2976),
#  ('of', 2169),
#  ('and', 1731),
#  ('to', 1072),
#  ('with', 936),
#  ('in', 927),
#  ('a', 914),
#  ('Rama', 800),
#  ('you', 658),
#  ('by', 621),
#  ('is', 560),
#  ('O', 550),
#  ('his', 502),
#  ('I', 499),
#  ('like', 457),
#  ('not', 373),
#  ('who', 365),
#  ('Sita', 354)]

# %% [markdown]
# ### Question 4 (Ramayana)
#
# What tokens have a length of greater than 5 and frequency of more than 150?
#
# *This function should return a sorted list of the tokens that match the above constraints. To sort your list, use `sorted()`*

# %%
def ramayana_answer_four():
    return sorted([token for token, freq in text_ramayana.vocab().items() if len(token) > 5 and freq > 150])

ramayana_answer_four()
# Out:
# ['Lakshmana', 'Ravana', 'arrows', 'demons', 'forest']

# %% [markdown]
# ### Question 5 (Ramayana)
#
# Find the longest word in text_ramayana and that word's length.
#
# *This function should return a tuple `(longest_word, length)`.*

# %%
import operator

def ramayana_answer_five():
    # Filter out non-alphabetic tokens and then find the longest word
    alpha_tokens = [token for token in text_ramayana if token.isalpha()]
    longest_word = max(alpha_tokens, key=len)
    return (longest_word, len(longest_word))

ramayana_answer_five()
# Out:
# ('quadranglestorturing', 20)

# %% [markdown]
# ### Question 6 (Ramayana)
#
# What unique words have a frequency of more than 2000? What is their frequency?
#
# "Hint:  you may want to use `isalpha()` to check if the token is a word and not punctuation."
#
# *This function should return a list of tuples of the form `(frequency, word)` sorted in descending order of frequency.*

# %%
import operator

def ramayana_answer_six():
    return sorted([(freq, token) for token, freq in text_ramayana.vocab().items() if freq > 2000 and token.isalpha()], key=operator.itemgetter(0), reverse=True)

ramayana_answer_six()
# Out:
# [(3407, 'the'), (2169, 'of')]

# %% [markdown]
# ### Question 7 (Ramayana)
#
# What is the average number of tokens per sentence?
#
# *This function should return a float.*

# %%
def ramayana_answer_seven():
    return np.mean([len(nltk.word_tokenize(sent)) for sent in nltk.sent_tokenize(ramayana_raw)])

ramayana_answer_seven()
# Out:
# np.float64(20.192393026941364)

# %% [markdown]
# ### Question 8 (Ramayana)
#
# What are the 5 most frequent parts of speech in this text? What is their frequency?
#
# *This function should return a list of tuples of the form `(part_of_speech, frequency)` sorted in descending order of frequency.*

# %%
from collections import Counter
import operator

def ramayana_answer_eight():
    # Ensure NLTK averaged_perceptron_tagger is downloaded
    nltk.download('averaged_perceptron_tagger', quiet=True)
    return sorted(Counter([tag for token, tag in nltk.pos_tag(text_ramayana)]).items(), key=operator.itemgetter(1), reverse=True)[:5]

ramayana_answer_eight()
# Out:
# [('NN', 8354), ('IN', 7752), ('DT', 5693), ('NNP', 4647), ('JJ', 3696)]

# %% [markdown]
# Question 9
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# Jaccard distance on the trigrams of the two words.
#
# This function should return a list of length three: ['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation'].

# %%
def answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.jaccard_distance(set(nltk.ngrams(entry, n=3)), set(nltk.ngrams(spell, n=3)))) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result # Your answer here

# Existing call to answer_nine for the Moby Dick section
# answer_nine()

def ramayana_answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    # This function is a replication of answer_nine for the Ramayana section.
    # The spelling recommender uses a general English word list (`correct_spellings`)
    # and not words specific to ramayana_tokens, so the logic and default entries are the same.
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.jaccard_distance(set(nltk.ngrams(entry, n=3)), set(nltk.ngrams(spell, n=3)))) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result

ramayana_answer_nine()
# Out:
# ['corpulent', 'indecence', 'validate']

# %% [markdown]
# Question 10
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# Jaccard distance on the 4-grams of the two words.
#
# This function should return a list of length three: ['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation'].

# %%
def answer_ten(entries=['cormulent', 'incendenece', 'validrate']):
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.jaccard_distance(set(nltk.ngrams(entry, n=4)), set(nltk.ngrams(spell, n=4)))) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result # Your answer here

# answer_ten()

def ramayana_answer_ten(entries=['cormulent', 'incendenece', 'validrate']):
    # This function is a replication of answer_ten for the Ramayana section.
    # The spelling recommender uses a general English word list (`correct_spellings`)
    # and not words specific to ramayana_tokens, so the logic and default entries are the same.
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.jaccard_distance(set(nltk.ngrams(entry, n=4)), set(nltk.ngrams(spell, n=4)))) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result

ramayana_answer_ten()
# Out:
# ['cormus', 'incendiary', 'valid']

# %% [markdown]
# ### Question 11 (Ramayana)
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Edit distance on the two words with transpositions.](https://en.wikipedia.org/wiki/Damerau%E2%80%93Levenshtein_distance)**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.

# %%
def ramayana_answer_eleven(entries=['cormulent', 'incendenece', 'validrate']):
    # This function is a replication of answer_eleven for the Ramayana section.
    # The spelling recommender uses a general English word list (`correct_spellings`)
    # and not words specific to ramayana_tokens, so the logic and default entries are the same.
    result = []
    import operator
    for entry in entries:
        spell_list = [spell for spell in correct_spellings if spell.startswith(entry[0]) and len(spell) > 2]
        distance_list = [(spell, nltk.edit_distance(entry, spell, transpositions=True)) for spell in spell_list]

        result.append(sorted(distance_list, key=operator.itemgetter(1))[0][0])

    return result

ramayana_answer_eleven()
# Out:
# ['corpulent', 'intendence', 'validate']
