# %% [markdown]
# ## Coding Exercise #0601

# %% [markdown]
# ### 1. String functions:

# %%
# To lowercase.
"HELLO! HOW ARE YOU?".lower()
# Out:
# 'hello! how are you?'

# %%
# To uppercase.
"this is a warning!".upper()
# Out:
# 'THIS IS A WARNING!'

# %%
# Split the string using a space as separator.
x = "Once uppon a time, there was a prince and a princess.".split(" ")

# %%
print(x)
# Out:
# ['Once', 'uppon', 'a', 'time,', 'there', 'was', 'a', 'prince', 'and', 'a', 'princess.']

# %%
# Join the list of string objects using a space as separator.
" ".join(x)
# Out:
# 'Once uppon a time, there was a prince and a princess.'

# %%
# Measure the length of a string object.
y = "Once uppon a time, there was a prince and a princess."
print(len(y))
# Out:
# 53

# %%
# Count the number of occurrences of 'a'.
y.count('a')
# Out:
# 5

# %%
# Sub-string.
y[0:10]
# Out:
# 'Once uppon'

# %% [markdown]
# ### 2. Regular expressions:

# %%
import re

# %% [markdown]
# #### 2.1. Metacharacter: Dot

# %%
# Target strings.
x1 = "ct"
x2 = "cat"
x3 = "caat"

# %%
# A regular expression.
my_expression = re.compile("c.t")

# %%
if my_expression.search(x1):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %%
if my_expression.search(x2):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if my_expression.search(x3):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %% [markdown]
# #### 2.2. Metacharacter: ?

# %%
# A regular expression.
my_exp = "ca?t"

# %%
if re.search(my_exp, x1):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if re.search(my_exp, x2):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if re.search(my_exp, x3):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %% [markdown]
# #### 2.3. Metacharacter: {m,n}

# %%
# Target strings.
x1 = "ct"
x2 = "cat"
x3 = "caat"
x4 = "caaat"

# %%
# A regular expression.
my_exp= "ca{1,2}t"

# %%
if re.search(my_exp, x1):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %%
if re.search(my_exp, x2):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if re.search(my_exp, x3):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if re.search(my_exp, x4):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %% [markdown]
# #### 2.4. Metacharacter: ^

# %%
# Target strings.
x1 = "That is your book."
x2 = "This is my book."

# %%
# A regular expression.
my_exp = "^This"

# %%
if re.search(my_exp, x1):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %%
if re.search(my_exp, x2):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %% [markdown]
# #### 2.5. Metacharacter: ^

# %%
# Target strings.
x1 = "I don't like you"
x2 = "You are great"
x3 = "in case you forget, remember this"

# %%
# A regular expression.
my_exp = "^[Ii]"

# %%
if re.search(my_exp, x1):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if re.search(my_exp, x2):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %%
if re.search(my_exp, x3):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %% [markdown]
# More examples:

# %%
# Target strings.
x1 = "This is year 2019"
x2 = "2000 is the year of my birth"

# %%
# A regular expression.
my_exp = "^[0-9]"

# %%
if re.search(my_exp, x1):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %%
if re.search(my_exp, x2):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %% [markdown]
# #### 2.6. Metacharacter: $

# %%
# Target strings.
x1 = "Python is easy"
x2 = "You need Python"

# %%
# A regular expression.
my_exp = "Python$"

# %%
if re.search(my_exp, x1):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %%
if re.search(my_exp, x2):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %% [markdown]
# #### 2.7. Metacharacter: |

# %%
# Target strings.
x1 = "I love you"
x2 = "I hate you"
x3 = "I like you"

# %%
# A regular expression.
my_exp = "love|hate"

# %%
if re.search(my_exp, x1):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if re.search(my_exp, x2):
    print("Yes!")
else:
    print("No")
# Out:
# Yes!

# %%
if re.search(my_exp, x3):
    print("Yes!")
else:
    print("No")
# Out:
# No

# %% [markdown]
# #### 2.8. sub() function:

# %%
# Target strings.
x1 = "Welcome to the year 2018"
x2 = "Just ~%* ++++--- arrived at @Jack's ##place."
x3 = "I                  love                you."

# %%
# Substitute the matching pattern with 'X'.
re.sub('\d','X',x1)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_13393/1871500113.py:2: SyntaxWarning: invalid escape sequence '\d'
#   re.sub('\d','X',x1)
# 'Welcome to the year XXXX'

# %%
# Substitute the matching pattern with space.
x2_modified = re.sub('[@~*#%+-]',' ',x2)
x2_modified
# Out:
# "Just             arrived at  Jack's   place."

# %%
# Remove the excessive spaces.
x2_final = re.sub('\s+',' ',x2_modified)
x2_final
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_13393/3412094408.py:2: SyntaxWarning: invalid escape sequence '\s'
#   x2_final = re.sub('\s+',' ',x2_modified)
# "Just arrived at Jack's place."

# %%
# Remove the excessive spaces.
re.sub('\s+',' ',x3)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_13393/268286320.py:2: SyntaxWarning: invalid escape sequence '\s'
#   re.sub('\s+',' ',x3)
# 'I love you.'
