# %% [markdown]
# ## Coding Exercise #0603

# %%
import re

# %% [markdown]
# ### 1. Regular expressions (groups):

# %% [markdown]
# #### 1.1. Some examples of group:

# %%
reg_ex = re.compile("([0-9]+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
# Out:
# 22

# %%
reg_ex = re.compile("([0-9]+)[^0-9]+([0-9]+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
print(m.group(2))
# Out:
# 22
# 20

# %%
reg_ex = re.compile("([^0-9]+)([0-9]+)[^0-9]+([0-9]+)[^0-9]+([0-9]+)")
m = reg_ex.search("John Wheeler 010-1234-5678")
print((m.group(1)).strip())
print(m.group(2))
print(m.group(3))
print(m.group(4))
# Out:
# John Wheeler
# 010
# 1234
# 5678

# %% [markdown]
# #### 1.2. Some exaples of group with shorthand expression:
# \d   =   [0-9]  <br>
# \D    =  [^0-9]  <br>
# \w   =   [0-9a-zA-Z_]  <br>
# \W    =  [^0-9a-zA-Z_]  <br>

# %%
reg_ex = re.compile("(\d+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
# Out:
# 22
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_3922/3715464251.py:1: SyntaxWarning: invalid escape sequence '\d'
#   reg_ex = re.compile("(\d+)")

# %%
reg_ex = re.compile("(\d+)\D+(\d+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
print(m.group(2))
# Out:
# 22
# 20
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_3922/4286642521.py:1: SyntaxWarning: invalid escape sequence '\d'
#   reg_ex = re.compile("(\d+)\D+(\d+)")

# %%
reg_ex = re.compile("(\D+)(\d+)\D+(\d+)\D+(\d+)")
m = reg_ex.search("John Wheeler 010-1234-5678")
print((m.group(1)).strip())
print(m.group(2))
print(m.group(3))
print(m.group(4))
# Out:
# John Wheeler
# 010
# 1234
# 5678
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_3922/4035954905.py:1: SyntaxWarning: invalid escape sequence '\D'
#   reg_ex = re.compile("(\D+)(\d+)\D+(\d+)\D+(\d+)")

# %%
# Hide the phone number.
reg_ex = re.compile("(\D+)(\d+)\D+(\d+)\D+(\d+)")
m = reg_ex.search("John Wheeler 010-1234-5678")
print((m.group(1)).strip() + " " + m.group(2) + "-****-****")
# Out:
# John Wheeler 010-****-****
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_3922/1442449437.py:2: SyntaxWarning: invalid escape sequence '\D'
#   reg_ex = re.compile("(\D+)(\d+)\D+(\d+)\D+(\d+)")

# %%
# Extract only the phone number.
reg_ex = re.compile("(\D+)((\d+)\D+(\d+)\D+(\d+))")
m = reg_ex.search("John Wheeler 010-1234-5678")
print("PHONE : " + m.group(2))
# Out:
# PHONE : 010-1234-5678
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_3922/1201817498.py:2: SyntaxWarning: invalid escape sequence '\D'
#   reg_ex = re.compile("(\D+)((\d+)\D+(\d+)\D+(\d+))")
