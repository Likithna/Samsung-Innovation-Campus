# %%
import numpy as np
scores = [3.0, 1.0, 0.2]
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    return np.exp(x) / np.sum(np.exp(x), axis = 0)

# %%
print(softmax(scores))
# Out:
# [0.8360188  0.11314284 0.05083836]

# %%
import matplotlib.pyplot as plt
x = np.arange(-2.0, 6.0, 0.1)
scores = np.vstack([x, np.ones_like(x), 0.2 * np.ones_like(x)])

plt.plot(x, softmax(scores).T, linewidth=2)
# Out:
# [<matplotlib.lines.Line2D at 0x77fe10834380>,
#  <matplotlib.lines.Line2D at 0x77fe108f87a0>,
#  <matplotlib.lines.Line2D at 0x77fe108350d0>]

# %%
plt.show()

# %%
scores = np.array([3.0, 1.0, 0.2])
softmax(scores * 10)
# Out:
# array([9.99999998e-01, 2.06115362e-09, 6.91440009e-13])

# %%
softmax(scores/10)
# Out:
# array([0.38842275, 0.31801365, 0.2935636 ])

# %%
import math
z = [1.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0]
z_expo = [math.exp(i) for i in z]
sum_z_expo = sum(z_expo)
softmax = [round(i/sum_z_expo, 3) for i in z_expo]
print(softmax)
# Out:
# [0.024, 0.064, 0.175, 0.475, 0.024, 0.064, 0.175]
